# %% [markdown]
# # Week 7 Instructor-led Lab: Data Manipulation

# %% [markdown]
# Author: Hali Evans
# Course: BGEN632
# Purpose: Inspect and organize data using pandas data frame and github data file.

# %% [markdown]
# ## Import Modules

# %%
import os
import pandas as pd
import numpy as np 
from sklearn.model_selection import KFold

# %% [markdown]
# ## Directory

# %%
os.getcwd() # gets directory
# Out:
# '/Users/halievans/Documents/BGEN632/week7labs'

# %%
os.chdir("/Users/halievans/Documents/BGEN632/week7labs/data") # sets directory

# %% [markdown]
# ## Accessing Data

# %%
gh_teams = pd.read_csv("github_teams.csv") # opens file

# %%
gh_teams.columns # returns column names
# Out:
# Index(['name_h', 'Team_type', 'Team_size_class', 'human_members_count',
#        'bot_members_count', 'human_work', 'work_per_human', 'human_gini',
#        'human_Push', 'human_IssueComments', 'human_PRReviewComment',
#        'human_MergedPR', 'bot_work', 'bot_Push', 'bot_IssueComments',
#        'bot_PRReviewComment', 'bot_MergedPR', 'eval_survival_day_median',
#        'issues_count'],
#       dtype='object')

# %%
gh_teams # determines number of rows = 608 and columns = 19 gh_teams.shape would have been another option to get the answer.
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ      human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg      human          Medium
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# ...

# %%
gh_teams.info() # determines name_h, Team_type, Team_size_class are categorical.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_h                    608 non-null    object
#  1   Team_type                 608 non-null    object
#  2   Team_size_class           608 non-null    object
#  3   human_members_count       608 non-null    int64
#  4   bot_members_count         608 non-null    int64
#  5   human_work                608 non-null    int64
#  6   work_per_human            608 non-null    float64
#  7   human_gini                608 non-null    float64
#  8   human_Push                608 non-null    int64
#  9   human_IssueComments       608 non-null    int64
#  10  human_PRReviewComment     608 non-null    int64
#  11  human_MergedPR            608 non-null    int64
#  12  bot_work                  608 non-null    int64
#  13  bot_Push                  608 non-null    int64
# ...

# %%
gh_teams['name_h'] = gh_teams['name_h'].astype('category') # converts object to category

# %%
gh_teams['Team_type'] = gh_teams['Team_type'].astype('category') # converts object to category

# %%
gh_teams['Team_size_class'] = gh_teams['Team_size_class'].astype('category') # converts object to category

# %%
gh_teams.info() # verifies object to category change
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_h                    608 non-null    category
#  1   Team_type                 608 non-null    category
#  2   Team_size_class           608 non-null    category
#  3   human_members_count       608 non-null    int64
#  4   bot_members_count         608 non-null    int64
#  5   human_work                608 non-null    int64
#  6   work_per_human            608 non-null    float64
#  7   human_gini                608 non-null    float64
#  8   human_Push                608 non-null    int64
#  9   human_IssueComments       608 non-null    int64
#  10  human_PRReviewComment     608 non-null    int64
#  11  human_MergedPR            608 non-null    int64
#  12  bot_work                  608 non-null    int64
# ...

# %%
gh_teams.Team_type.unique() # Team_type unique values = 2
# Out:
# ['human-bot', 'human']
# Categories (2, object): ['human', 'human-bot']

# %%
gh_teams.Team_size_class.unique() # Team_size_class unique values = 3
# Out:
# ['Small', 'Large', 'Medium']
# Categories (3, object): ['Large', 'Medium', 'Small']

# %%
gh_teams.iloc[62, 5] # value at 63rd row and 6th column
# Out:
# 35

# %%
gh_teams.iloc[299] # values in the 300th row
# Out:
# name_h                      IyfocAGfAHLncCVJUujqTA/A_QZ6HlUb5sRQHhPa7SGzQ
# Team_type                                                       human-bot
# Team_size_class                                                    Medium
# human_members_count                                                     4
# bot_members_count                                                       1
# human_work                                                           1049
# work_per_human                                                     262.25
# human_gini                                                       0.448761
# human_Push                                                            739
# human_IssueComments                                                   213
# human_PRReviewComment                                                  91
# human_MergedPR                                                          6
# bot_work                                                               52
# ...

# %%
gh_teams.iloc[595, :3] # method 1 selects row with index value 595 with 1st, 2nd, 3rd columns.
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[595, [0, 1, 2]] # method 2 selects row with index value 595 with 1st, 2nd, 3rd columns.
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[595, 0:3] # method 3 selects row with index value 595 with 1st, 2nd, 3rd columns.
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[46, [2, 6]] # method 1 selects row with index value 46 with the 3rd and 7th column
# Out:
# Team_size_class       Medium
# work_per_human     31.833333
# Name: 46, dtype: object

# %%
gh_teams.loc[46, ['Team_size_class', 'work_per_human']] # method 2 selects row with index value 46 with the 3rd and 7th column
# Out:
# Team_size_class       Medium
# work_per_human     31.833333
# Name: 46, dtype: object

# %%
just_bot_work = pd.DataFrame(gh_teams.bot_work) # method 1 creates new dataframe column
just_bot_work
# Out:
#      bot_work
# 0          43
# 1           0
# 2           0
# 3        1972
# 4         302
# ..        ...
# 603        26
# 604         0
# 605         0
# 606         0
# 607         8
#
# [608 rows x 1 columns]

# %%
just_bot_work = gh_teams[['bot_work']] # method 2 creates new dataframe column
just_bot_work
# Out:
#      bot_work
# 0          43
# 1           0
# 2           0
# 3        1972
# 4         302
# ..        ...
# 603        26
# 604         0
# 605         0
# 606         0
# 607         8
#
# [608 rows x 1 columns]

# %% [markdown]
# ## Sorting and Ordering data

# %%
gh_teams[(gh_teams['Team_type'] == 'human-bot') & (gh_teams['bot_members_count'] >= 2)] # selects human-bot teams that have a bot_members_count value greater than or equal to 2
# Out:
#                                             name_h  Team_type Team_size_class  \
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# 42   2-scMrZv13F95YPZmfieww/4Zc56iUYjIZrZU06omFrJw  human-bot           Large
# 84   4YoH8row044yJjPIqWJw9Q/NSXj3i61X71lV0StTN71Ww  human-bot           Small
# 89   5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
# 110  7sA-8-nyqr0Ri2CT4-FSZw/GJPQoUhHfvUsxKcdkHWLEw  human-bot           Small
# 146  bi5TY2Z4OSQq3PMs6JnKYA/5wtZcUUo1XmLHIra8NDtFQ  human-bot          Medium
# 147  bi5TY2Z4OSQq3PMs6JnKYA/9b9IqkDK14ketwn88f3hKA  human-bot           Small
# 149  bi5TY2Z4OSQq3PMs6JnKYA/kIiAIJpk6lOa6Nxf234KkQ  human-bot           Small
# 224  FAhkB4rsocfDW0vrM8U8NA/3KHgTzOwWtAxTXlp_mbqoA  human-bot           Large
# 229  FAhkB4rsocfDW0vrM8U8NA/Tl_ZLGwQZrAi-GHyEKl_jA  human-bot           Large
# ...

# %%
gh_teams[(gh_teams['Team_type'] == 'human') & (gh_teams['Team_size_class'] == 'Large') & (gh_teams['human_gini'] >= 0.75)] # finds human teams that are Large and have a human-gini value greater than and equal to .75
# Out:
#                                             name_h Team_type Team_size_class  \
# 138  ASYGR96YA91p3z7MNKjZCA/IB2pZ8ygcvNnlxUdysjSFA     human           Large
# 285  IiUao8vA_zm_uEIVVLI-Sw/91ya8vlSP8qgwCllH_6BSw     human           Large
# 505  uLHPO58cQefwrJUbyhYOKQ/7YWOP8uDEeKDHQMWKqOoYA     human           Large
# 582  y8Jw59EHVSrsluSuhR5okg/V5vb074jNkzg4YCKforX1Q     human           Large
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 138                   12                  0        1655      137.916667
# 285                   25                  0        3599      143.960000
# 505                   48                  0        5748      119.750000
# 582                    8                  0         277       34.625000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 138    0.799446         793                  684                    178
# 285    0.863507        1249                 2350                      0
# ...

# %%
len(gh_teams[(gh_teams['Team_size_class'] == 'Large') | (gh_teams['Team_size_class'] == 'Small')]) # count of teams in small or large category
# Out:
# 428

# %%
len(gh_teams[((gh_teams['Team_size_class'] == 'Large') | (gh_teams['Team_size_class'] == 'Small')) & (gh_teams['human_gini'] <= 0.20)]) # count of teams in small or large category with human-gini less than and equal to .20
# Out:
# 66

# %%
len(gh_teams[((gh_teams['Team_type'] == 'human-bot') & (gh_teams['Team_size_class'] == 'Medium'))]) # count of human-bot teams in medium category.
# Out:
# 84

# %%
gh_teams_subsample = gh_teams.sample(frac = .5, replace = False) # creates subsample of 50% data
len(gh_teams_subsample.index)
# Out:
# 304

# %%
kf = KFold(n_splits = 8) # creates samples for 8-fold cross validation test

# %%
num_df = gh_teams.select_dtypes(include = ['number']) # selects numberic columns and saves as new DataFrame

# %%
gh_teams.drop(['bot_PRReviewComment', 'bot_MergedPR'], axis = 1) # removes bot_PRReviewComment and bot_MergedPR from DataFrame
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ      human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg      human          Medium
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# ...

# %%
tsc_hmc_df = gh_teams[['Team_size_class', 'human_members_count']] # saves columns Teams_size_class and human_members_count as new DataFrame

# %%
tsc_hmc_df.rename(columns={'Team_size_class' : 'Team_size', 'human_members_count' : 'human_count'}) # renames Teams_size_class and human_members_count in new DataFrame.
# Out:
#     Team_size  human_count
# 0       Small            2
# 1       Small            2
# 2       Large            7
# 3       Large          234
# 4       Large           38
# ..        ...          ...
# 603     Small            3
# 604     Small            2
# 605    Medium            5
# 606    Medium            5
# 607     Small            2
#
# [608 rows x 2 columns]
